# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
import random
import time
import pandas as pd
import requests

# %%
df = pd.read_csv('listsp500')
df.head()
# Out:
#    Unnamed: 0 Symbol     Security SEC filings  GICS Sector  \
# 0           0    MMM           3M     reports  Industrials
# 1           1    AOS  A. O. Smith     reports  Industrials
# 2           2    ABT       Abbott     reports  Health Care
# 3           3   ABBV       AbbVie     reports  Health Care
# 4           4   ABMD      Abiomed     reports  Health Care
#
#           GICS Sub-Industry    Headquarters Location Date first added  \
# 0  Industrial Conglomerates    Saint Paul, Minnesota       1976-08-09
# 1         Building Products     Milwaukee, Wisconsin       2017-07-26
# 2     Health Care Equipment  North Chicago, Illinois       1964-03-31
# 3           Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 4     Health Care Equipment   Danvers, Massachusetts       2018-05-31
#
#        CIK      Founded
# 0    66740         1902
# 1    91142         1916
# 2     1800         1888
# 3  1551152  2013 (1888)
# 4   815094         1981

# %%
df['GICS Sector'].value_counts()
# Out:
# Information Technology    74
# Industrials               73
# Financials                66
# Health Care               65
# Consumer Discretionary    60
# Consumer Staples          32
# Real Estate               30
# Utilities                 29
# Materials                 28
# Communication Services    27
# Energy                    21
# Name: GICS Sector, dtype: int64

# %%
list_of_companies = df.sample(n=100)

# %%
def getting_company_reviews_urls_bs(companies):
    """
    Takes a list of company names as input and returns the url of the review section of each company in a dataframe
    """
    driver = webdriver.Chrome('/Users/corentin/Documents/chromedriver')
    time.sleep(5)
    url = 'https://www.glassdoor.com/Reviews/index.htm'
    search_bar_xpath = '//*[@id="KeywordSearch"]'
    df = pd.DataFrame({'company': [], 'link': []})
    domain = 'https://fr.glassdoor.be'

    
    for company in companies:
        try:
            #Searching for the company
            driver.get(url)
            time.sleep(random.uniform(2, 4))
            company_search = driver.find_element_by_xpath(search_bar_xpath)
            company_search.send_keys(company)
            time.sleep(random.uniform(1, 2))
            company_search.send_keys(Keys.ENTER)

            #Going on the first company's page
            time.sleep(random.uniform(2, 4))
            driver.find_element_by_xpath('//*[@id="MainCol"]/div/div[1]/div/div[1]/div/div[2]/h2/a').click()
            # soup = BeautifulSoup(driver.page_source, 'lxml')
            # first_company_box = domain + soup.find('a', class_ = 'sqLogoLink').get('href')

            #Going in the reviews section of the page and getting the url
            time.sleep(random.uniform(2, 4))
            # sauce = requests.get(first_company_box)
            # soup = BeautifulSoup(sauce.text, 'lxml')
            soup = BeautifulSoup(driver.page_source, 'lxml')
            reviews_url = domain + soup.find('a', class_ = 'd-flex align-items-center pt-std css-1qnp674 e16bqfyh1').get('href')
            #reviews_url = domain + soup.find('a', {'data-test': 'reviewSeeAllLink'}).get('href')
            #reviews_url = soup.find('a', class_ 'eiCell cell reviews ').get('href')
            print('Reviews for ' + company + reviews_url)
            print('Search for the company succesful')

            #Populating the dataframe
            df = df.append({'company': company, 'link': reviews_url}, ignore_index=True)
        except:
            continue
    
    return df

# %%
#df = getting_company_reviews_urls_bs(list_of_companies['Security'])
# Out:
# Reviews for Cignahttps://fr.glassdoor.be/Avis/Cigna-Avis-E119.htm
# Search for the company succesful
# Reviews for NXPhttps://fr.glassdoor.be/Avis/NXP-Semiconductors-Avis-E13528.htm
# Search for the company succesful
# Reviews for MSCIhttps://fr.glassdoor.be/Avis/MSCI-Avis-E14616.htm
# Search for the company succesful
# Reviews for Catalenthttps://fr.glassdoor.be/Avis/Catalent-Pharma-Avis-E43266.htm
# Search for the company succesful
# Reviews for Iron Mountainhttps://fr.glassdoor.be/Avis/Iron-Mountain-Avis-E6774.htm
# Search for the company succesful
# Reviews for Targethttps://fr.glassdoor.be/Avis/Target-Avis-E194.htm
# Search for the company succesful
# Reviews for Trimblehttps://fr.glassdoor.be/Avis/Trimble-Avis-E2067.htm
# Search for the company succesful
# Reviews for Garminhttps://fr.glassdoor.be/Avis/Garmin-Avis-E12667.htm
# Search for the company succesful
# Reviews for Take-Two Interactivehttps://fr.glassdoor.be/Avis/Take-Two-Avis-E7413.htm
# Search for the company succesful
# Reviews for Akamaihttps://fr.glassdoor.be/Avis/Akamai-Avis-E9219.htm
# Search for the company succesful
# Reviews for Trane Technologieshttps://fr.glassdoor.be/Avis/Trane-Technologies-Avis-E349.htm
# Search for the company succesful
# Reviews for Invescohttps://fr.glassdoor.be/Avis/Invesco-Avis-E4518.htm
# Search for the company succesful
# Reviews for Lockheed Martinhttps://fr.glassdoor.be/Avis/Lockheed-Martin-Avis-E404.htm
# Search for the company succesful
# Reviews for Fastenalhttps://fr.glassdoor.be/Avis/Fastenal-Avis-E1391.htm
# Search for the company succesful
# Reviews for Best Buyhttps://fr.glassdoor.be/Avis/Best-Buy-Avis-E97.htm
# Search for the company succesful
# Reviews for Principalhttps://fr.glassdoor.be/Avis/PwC-Avis-E8450.htm
# Search for the company succesful
#     company                                               link
# 0   Comcast  https://fr.glassdoor.be/Avis/Comcast-Avis-E128...
# 1   Centene  https://fr.glassdoor.be/Avis/Centene-Avis-E135...
# 2     Xylem  https://fr.glassdoor.be/Avis/Xylem-Avis-E49485...
# 3  Grainger  https://fr.glassdoor.be/Avis/Grainger-Avis-E71...
# 4       FMC     https://fr.glassdoor.be/Avis/FMC-Avis-E239.htm

# %%
## Code to remove annoying login overlay 
# driver.execute_script("""
# javascript:(function(){
#   document.getElementsByClassName('hardsellOverlay')[0].remove();
#   document.getElementsByTagName("body")[0].style.overflow = "scroll";
#   let style = document.createElement('style');
#   style.innerHTML = `
#     #LoginModal {
#       display: none!important;
#     }
#   `;
#   document.head.appendChild(style);
#   window.addEventListener("scroll", function (event) {
#     event.stopPropagation();
#   }, true);
# })();
# """)

# %%
df.to_csv('a_few_links')
